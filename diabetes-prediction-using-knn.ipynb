# %%
#import libraries

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#load data

data = pd.read_csv("Dataset/diabetes-data.csv")

# %%
#Analysis of data

data
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 768 entries, 0 to 767
# Data columns (total 9 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Pregnancies               768 non-null    int64
#  1   Glucose                   768 non-null    int64
#  2   BloodPressure             768 non-null    int64
#  3   SkinThickness             768 non-null    int64
#  4   Insulin                   768 non-null    int64
#  5   BMI                       768 non-null    float64
#  6   DiabetesPedigreeFunction  768 non-null    float64
#  7   Age                       768 non-null    int64
#  8   Outcome                   768 non-null    int64
# dtypes: float64(2), int64(7)
# memory usage: 54.1 KB

# %%
data.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
data.tail()
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 763                     0.171   63        0
# 764                     0.340   27        0
# 765                     0.245   30        0
# 766                     0.349   47        1
# 767                     0.315   23        0

# %%
data.describe()
# Out:
#        Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# count   768.000000  768.000000     768.000000     768.000000  768.000000
# mean      3.845052  120.894531      69.105469      20.536458   79.799479
# std       3.369578   31.972618      19.355807      15.952218  115.244002
# min       0.000000    0.000000       0.000000       0.000000    0.000000
# 25%       1.000000   99.000000      62.000000       0.000000    0.000000
# 50%       3.000000  117.000000      72.000000      23.000000   30.500000
# 75%       6.000000  140.250000      80.000000      32.000000  127.250000
# max      17.000000  199.000000     122.000000      99.000000  846.000000
#
#               BMI  DiabetesPedigreeFunction         Age     Outcome
# count  768.000000                768.000000  768.000000  768.000000
# mean    31.992578                  0.471876   33.240885    0.348958
# std      7.884160                  0.331329   11.760232    0.476951
# ...

# %%
data.isnull()
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin    BMI  \
# 0          False    False          False          False    False  False
# 1          False    False          False          False    False  False
# 2          False    False          False          False    False  False
# 3          False    False          False          False    False  False
# 4          False    False          False          False    False  False
# ..           ...      ...            ...            ...      ...    ...
# 763        False    False          False          False    False  False
# 764        False    False          False          False    False  False
# 765        False    False          False          False    False  False
# 766        False    False          False          False    False  False
# 767        False    False          False          False    False  False
#
#      DiabetesPedigreeFunction    Age  Outcome
# 0                       False  False    False
# ...

# %%
data.isnull().sum()
# Out:
# Pregnancies                 0
# Glucose                     0
# BloodPressure               0
# SkinThickness               0
# Insulin                     0
# BMI                         0
# DiabetesPedigreeFunction    0
# Age                         0
# Outcome                     0
# dtype: int64

# %%
data.describe().T
# Out:
#                           count        mean         std     min       25%  \
# Pregnancies               768.0    3.845052    3.369578   0.000   1.00000
# Glucose                   768.0  120.894531   31.972618   0.000  99.00000
# BloodPressure             768.0   69.105469   19.355807   0.000  62.00000
# SkinThickness             768.0   20.536458   15.952218   0.000   0.00000
# Insulin                   768.0   79.799479  115.244002   0.000   0.00000
# BMI                       768.0   31.992578    7.884160   0.000  27.30000
# DiabetesPedigreeFunction  768.0    0.471876    0.331329   0.078   0.24375
# Age                       768.0   33.240885   11.760232  21.000  24.00000
# Outcome                   768.0    0.348958    0.476951   0.000   0.00000
#
#                                50%        75%     max
# Pregnancies                 3.0000    6.00000   17.00
# Glucose                   117.0000  140.25000  199.00
# BloodPressure              72.0000   80.00000  122.00
# ...

# %% [markdown]
# We notice that the minimum value of certain fields is zero. The zero value for columns such as Glucose, etc does not make sense. This may be due to missing values
#
# The following fields have an invalid zero value
#
# Glucose,
# BloodPressure,
# SkinThickness,
# Insulin,
# BMI.
#
# We can handle the invalid zero values by replacing them with NaN. This step will help count them easily. We need to replace the zeros with suitable values.
#
# We copy the dataframe to a new dataframe and then replace the zero values in the above given 5 variables with NaN.

# %%
#copy data to a new dataframe
data_copy = data.copy(deep=True)

# %%
data_copy[['Glucose','BloodPressure','SkinThickness','Insulin','BMI']] = data_copy[['Glucose','BloodPressure','SkinThickness','Insulin','BMI']].replace(0,np.NAN)

# %%
data_copy.isnull().sum()
# Out:
# Pregnancies                   0
# Glucose                       5
# BloodPressure                35
# SkinThickness               227
# Insulin                     374
# BMI                          11
# DiabetesPedigreeFunction      0
# Age                           0
# Outcome                       0
# dtype: int64

# %%
data_copy
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6    148.0           72.0           35.0      NaN  33.6
# 1              1     85.0           66.0           29.0      NaN  26.6
# 2              8    183.0           64.0            NaN      NaN  23.3
# 3              1     89.0           66.0           23.0     94.0  28.1
# 4              0    137.0           40.0           35.0    168.0  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10    101.0           76.0           48.0    180.0  32.9
# 764            2    122.0           70.0           27.0      NaN  36.8
# 765            5    121.0           72.0           23.0    112.0  26.2
# 766            1    126.0           60.0            NaN      NaN  30.1
# 767            1     93.0           70.0           31.0      NaN  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# ...

# %%
plot = data.hist(figsize =(20,20))

# %% [markdown]
# Now we replace the NAN values with the mean value of the variable.
#
# For each of the column, the NAN value is replaced with mean() value

# %%
data_copy['Glucose'].fillna(data_copy['Glucose'].mean(),inplace=True)
data_copy['BloodPressure'].fillna(data_copy['BloodPressure'].mean(),inplace=True)
data_copy['SkinThickness'].fillna(data_copy['SkinThickness'].median(),inplace=True)
data_copy['Insulin'].fillna(data_copy['Insulin'].median(),inplace=True)
data_copy['BMI'].fillna(data_copy['BMI'].mean(),inplace=True)

# %%
#Now we plot the histogram of updated data and analyze the changes due to the previous step

data_copy.hist(figsize=(20,20))
# Out:
# array([[<AxesSubplot:title={'center':'Pregnancies'}>,
#         <AxesSubplot:title={'center':'Glucose'}>,
#         <AxesSubplot:title={'center':'BloodPressure'}>],
#        [<AxesSubplot:title={'center':'SkinThickness'}>,
#         <AxesSubplot:title={'center':'Insulin'}>,
#         <AxesSubplot:title={'center':'BMI'}>],
#        [<AxesSubplot:title={'center':'DiabetesPedigreeFunction'}>,
#         <AxesSubplot:title={'center':'Age'}>,
#         <AxesSubplot:title={'center':'Outcome'}>]], dtype=object)

# %% [markdown]
# # Exploratory Data Analysis

# %%
#analysis shape of data


data_copy.shape

#The shape of the data shows that there are 768 records and 9 variables
# Out:
# (768, 9)

# %%
#Analyze the Outcome Variable

print(data_copy.Outcome.value_counts())

data_copy.Outcome.value_counts().plot(kind='bar')
# Out:
# 0    500
# 1    268
# Name: Outcome, dtype: int64
# <AxesSubplot:>

# %%
#scatter matrix for unclean data


from pandas.plotting import scatter_matrix
scatter_matrix(data,figsize=(25,25))
# Out:
# array([[<AxesSubplot:xlabel='Pregnancies', ylabel='Pregnancies'>,
#         <AxesSubplot:xlabel='Glucose', ylabel='Pregnancies'>,
#         <AxesSubplot:xlabel='BloodPressure', ylabel='Pregnancies'>,
#         <AxesSubplot:xlabel='SkinThickness', ylabel='Pregnancies'>,
#         <AxesSubplot:xlabel='Insulin', ylabel='Pregnancies'>,
#         <AxesSubplot:xlabel='BMI', ylabel='Pregnancies'>,
#         <AxesSubplot:xlabel='DiabetesPedigreeFunction', ylabel='Pregnancies'>,
#         <AxesSubplot:xlabel='Age', ylabel='Pregnancies'>,
#         <AxesSubplot:xlabel='Outcome', ylabel='Pregnancies'>],
#        [<AxesSubplot:xlabel='Pregnancies', ylabel='Glucose'>,
#         <AxesSubplot:xlabel='Glucose', ylabel='Glucose'>,
#         <AxesSubplot:xlabel='BloodPressure', ylabel='Glucose'>,
#         <AxesSubplot:xlabel='SkinThickness', ylabel='Glucose'>,
#         <AxesSubplot:xlabel='Insulin', ylabel='Glucose'>,
#         <AxesSubplot:xlabel='BMI', ylabel='Glucose'>,
# ...

# %%
#pair plot for clean data

sns.pairplot(data_copy,hue='Outcome')

# %%
#We can construct a heat map to visualize the correlation matrix

# %%
#create heat map for unclean data

sns.heatmap(data.corr(), annot=True,cmap ='RdYlGn')
# Out:
# <AxesSubplot:>

# %%
#create heatmap for clean data

p=sns.heatmap(data_copy.corr(), annot=True,cmap ='RdYlGn')

# %% [markdown]
# # Scaling

# %%
from sklearn.preprocessing import StandardScaler

# %%
#initialize scaler
scaler = StandardScaler()

# %%
#fit data to scaler object

X = scaler.fit_transform(data_copy.drop(['Outcome'],axis=1))
X = pd.DataFrame(X,columns=['Pregnancies', 'Glucose', 'BloodPressure', 'SkinThickness', 'Insulin', 'BMI', 'DiabetesPedigreeFunction', 'Age'])

# %%
X
# Out:
#      Pregnancies   Glucose  BloodPressure  SkinThickness   Insulin       BMI  \
# 0       0.639947  0.865108      -0.033518       0.670643 -0.181541  0.166292
# 1      -0.844885 -1.206162      -0.529859      -0.012301 -0.181541 -0.852531
# 2       1.233880  2.015813      -0.695306      -0.012301 -0.181541 -1.332833
# 3      -0.844885 -1.074652      -0.529859      -0.695245 -0.540642 -0.634212
# 4      -1.141852  0.503458      -2.680669       0.670643  0.316566  1.548980
# ..           ...       ...            ...            ...       ...       ...
# 763     1.827813 -0.680125       0.297376       2.150354  0.455573  0.064409
# 764    -0.547919  0.010298      -0.198965      -0.239949 -0.181541  0.632039
# 765     0.342981 -0.022579      -0.033518      -0.695245 -0.332132 -0.910750
# 766    -0.844885  0.141808      -1.026200      -0.012301 -0.181541 -0.343120
# 767    -0.844885 -0.943143      -0.198965       0.215347 -0.181541 -0.299456
#
#      DiabetesPedigreeFunction       Age
# ...

# %%
X.head()
# Out:
#    Pregnancies   Glucose  BloodPressure  SkinThickness   Insulin       BMI  \
# 0     0.639947  0.865108      -0.033518       0.670643 -0.181541  0.166292
# 1    -0.844885 -1.206162      -0.529859      -0.012301 -0.181541 -0.852531
# 2     1.233880  2.015813      -0.695306      -0.012301 -0.181541 -1.332833
# 3    -0.844885 -1.074652      -0.529859      -0.695245 -0.540642 -0.634212
# 4    -1.141852  0.503458      -2.680669       0.670643  0.316566  1.548980
#
#    DiabetesPedigreeFunction       Age
# 0                  0.468492  1.425995
# 1                 -0.365061 -0.190672
# 2                  0.604397 -0.105584
# 3                 -0.920763 -1.041549
# 4                  5.484909 -0.020496

# %% [markdown]
# # Train Test Split

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.neighbors import KNeighborsClassifier

# %%
y = data_copy.Outcome

# %%
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=1/3,random_state=42,stratify=y)

# %% [markdown]
# # Data Modeling

# %%
#Use KNN Algo
#We have used a for loop to fit the data on KNN model with K=1,......,15 and store the scores

# %%
from sklearn.neighbors import KNeighborsClassifier

# %%
#to store the result

testing_score =[]
training_score=[]

# %%
for i in range(1,15):
    knn = KNeighborsClassifier(i)
    knn.fit(X_train,y_train)
    
    
    training_score.append(knn.score(X_train,y_train))
    testing_score.append(knn.score(X_test,y_test))

# %%
#Check out the value of K for which the training accuracy was the highest

max_training_score = max(training_score)

train_scores_ind = [i for i, v in enumerate(training_score) if v == max_training_score]
print('Max training score {} % and k = {}'.format(max_training_score*100,list(map(lambda x: x+1, train_scores_ind))))
# Out:
# Max training score 100.0 % and k = [1]

# %%
#Check out the value of K for which the testing accuracy was the highest

max_testing_score = max(testing_score)
test_scores_ind = [i for i, v in enumerate(testing_score) if v == max_testing_score]
print('Max testing score {} % and k = {}'.format(max_testing_score*100,list(map(lambda x: x+1, test_scores_ind))))
# Out:
# Max testing score 76.5625 % and k = [11]

# %%
# Hence for the given data set, we can select the KNN with K=11

# %%
plt.plot(training_score,label='Training_score')
plt.plot(testing_score,label='Testing_score')
leg = plt.legend(loc='upper center')
plt.show()

# %%
knn = KNeighborsClassifier(11)

# %%
knn.fit(X_train,y_train)
knn.score(X_test,y_test)
# Out:
# 0.765625

# %%
#prediction using test data
y_pred = knn.predict(X_test)

# %%
#calculate model accuracy by comparing (y_test,y_pred)

from sklearn.metrics import accuracy_score

acc_knn = round(accuracy_score(y_test,y_pred) *100,2)
print('Accuracy of KNeighborsClassifier : ',acc_knn)
# Out:
# Accuracy of KNeighborsClassifier :  76.56
